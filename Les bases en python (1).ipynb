# %% [markdown]
# # Apprendre les bases en Python

# %% [markdown]
# ## ⌨️ Saisie au clavier & print()
#
# - input() permet de demander une valeur à l'utilisateur.
#
# - Elle est toujours renvoyée en texte (str).

# %%
nom = input("Quel est ton prénom ? ")
print("Bonjour", nom)
# Out:
# Quel est ton prénom ?  dd
# Bonjour dd

# %% [markdown]
# ### 🎯 Convertir une saisie

# %%
age = int(input("Quel est ton âge ? "))   # str → int
taille = float(input("Ta taille en m ? "))  # str → float
# Out:
# Quel est ton âge ?  1
# Ta taille en m ?  3

# %% [markdown]
# ⚠️ Si l’utilisateur tape autre chose qu’un nombre, cela provoque une erreur (à intercepter avec try/except si besoin).

# %% [markdown]
# ### 🖨 Affichage avec print()

# %%
print("Bonjour le monde !")
# Out:
# Bonjour le monde !

# %% [markdown]
# ### 🔗 Afficher plusieurs éléments

# %%
prenom = "Léo"
print("Bienvenue", prenom, "!")
# Out:
# Bienvenue Léo !

# %% [markdown]
# ### 🎯 Affichage formaté (f-string)

# %%
age = 20
print(f"Tu as {age} ans.")   # plus lisible et propre
# Out:
# Tu as 20 ans.

# %% [markdown]
# ### ✂️ Échapper un saut de ligne

# %%
print("Bonjour", end=" → ")
print("suite sur la même ligne")  # Bonjour → suite sur la même ligne
# Out:
# Bonjour → suite sur la même ligne

# %% [markdown]
# ### 🧠 Exercice
# ### ✏️ Énoncé :
#
# 1) Demande à l'utilisateur :
#
# - son prénom
#
# - son âge
#
# - sa ville
#
# 2) Affiche un message comme :
#
# Bonjour Sam, tu as 16 ans et tu habites à Lyon.

# %%
nom = input("Quel est ton prénom ? ")
age = int(input("Quel est ton âge ? ")) 
ville = input("Quel est ta ville ? ")

print("Bonjour", nom, ", tu as ", age , "ans " " tu habite à " ,ville , )

# %% [markdown]
# ## Variables : création ▸ lecture ▸ réassignation (int, float, str, bool)

# %% [markdown]
# ### 🔢 int — nombres entiers

# %%
age = 20              # création
print(age)            # lecture
age = age + 1         # réassignation (incrément)
print(age)            # affiche 21
# Out:
# 20
# 21

# %% [markdown]
# ### 🌡 float — nombres à virgule

# %%
temperature = 36.6
print(temperature)
temperature = temperature + 1.2
print(temperature)    # 37.8
# Out:
# 36.6
# 37.800000000000004

# %% [markdown]
# ### 📝 str — chaînes de caractères

# %%
prenom = "Alice"
print(prenom)
prenom = prenom + " Dupont"
print(prenom)         # Alice Dupont
# Out:
# Alice
# Alice Dupont

# %% [markdown]
# ### ✅ bool — valeurs vraies/faux

# %%
majeur = age >= 18
print(majeur)         # True
majeur = False
print(majeur)         # False
# Out:
# True
# False

# %% [markdown]
# ### 🧠 Petit exercice à faire

# %% [markdown]
# ✏️ Énoncé :
# Crée un petit script Python qui :
#
# Demande le prénom et l'âge de l'utilisateur.
#
# Calcule son année de naissance (en supposant qu’on est en 2025).
#
# Affiche un message personnalisé :
#
# Bonjour Alice, tu es né(e) en 2005. Tu es majeur : True

# %%
# Votre code ici

# %% [markdown]
# ## 🔧 Opérateurs arithmétiques (int / float)

# %%
a = 7
b = 3
print("a + b =", a + b) # addition
print("a * b =", a * b) # multiplication
print("a / b =", a / b) # division entière
print("a % b =", a % b) # modulo
print("a ** b =", a ** b) #puissance
# Out:
# a + b = 10
# a * b = 21
# a / b = 2.3333333333333335
# a % b = 1
# a ** b = 343

# %% [markdown]
# ## ⚖️ Opérateurs logiques (bool)

# %%
age = 17
a_le_droit = age >= 18
print("Est majeur :", a_le_droit)        # False

mot_de_passe_correct = True
est_connecte = mot_de_passe_correct and a_le_droit
print("Connexion possible :", est_connecte)  # False
# Out:
# Est majeur : False
# Connexion possible : False

# %% [markdown]
# ## 🎯 Exercice
# ✏️ Énoncé :
# Demander l’âge d’un utilisateur.
#
# Demander s’il a une carte d’identité (oui ou non).
#
# Afficher s’il peut entrer dans une discothèque.
# Il doit :
#
# avoir au moins 18 ans ET
#
# avoir une carte d’identité.

# %%
# Votre code ici

# %% [markdown]
# # 🧵 Chaînes de caractères (str)
# ### Une chaîne de caractères est un texte encadré par " " ou ' '.
# ### Elle peut être manipulée, concaténée, découpée, mesurée, etc.

# %% [markdown]
# ### 🔧 Création et lecture

# %%
prenom = "Alice"
message = 'Bonjour'
print(prenom)     # Alice
print(message)    # Bonjour
# Out:
# Alice
# Bonjour

# %% [markdown]
# ### 🔗 Concaténation

# %%
full_name = "Alice" + " " + "Dupont"
print(full_name)   # Alice Dupont
# Out:
# Alice Dupont

# %% [markdown]
# ### 🔁 Répétition

# %%
rire = "ha" * 3
print(rire)        # hahaha
# Out:
# hahaha

# %% [markdown]
# ### 📏 Longueur

# %%
texte = "Python"
print(len(texte))  # 6
# Out:
# 6

# %% [markdown]
# ### 🔤 Majuscules / minuscules

# %%
mot = "Bonjour"
print(mot.upper())  # BONJOUR
print(mot.lower())  # bonjour
# Out:
# BONJOUR
# bonjour

# %% [markdown]
# ### 🎯 Recherche / inclusion

# %%
phrase = "Il fait beau aujourd'hui"
print("beau" in phrase)      # True
print("pluie" in phrase)     # False
# Out:
# True
# False

# %% [markdown]
# ### 🧪 Exemple combiné

# %%
prenom = "Léo"
nom = "Martin"
message = f"Bonjour {prenom} {nom} !"
print(message)  # Bonjour Léo Martin !
# Out:
# Bonjour Léo Martin !

# %% [markdown]
# ### 🧠 Exercice
# #### ✏️ Énoncé :
#
# 1) Demander à l’utilisateur :
#
# - son prénom
#
# - son nom
#
# - et son âge
#
# 2) Afficher un message de bienvenue du type :
#
# Bonjour Léo Martin ! Ton prénom contient 3 lettres.
# Tu as 18 ans : c’est court mais prometteur.

# %%
# Votre code ici

# %% [markdown]
# # 📚 Listes en Python

# %% [markdown]
# ### 🔧 Création et lecture

# %%
fruits = ["pomme", "banane", "cerise"]
print(fruits)          # ['pomme', 'banane', 'cerise']
print(fruits[0])       # pomme (premier élément)
print(fruits[-1])      # cerise (dernier élément)
# Out:
# ['pomme', 'banane', 'cerise']
# pomme
# cerise

# %% [markdown]
# ### ➕ Ajouter un élément

# %%
fruits.append("kiwi")
print(fruits)          # ['pomme', 'banane', 'cerise', 'kiwi']
# Out:
# ['pomme', 'banane', 'cerise', 'kiwi']

# %% [markdown]
# ### 🗑 Supprimer un élément

# %%
fruits.remove("banane")  # supprime par valeur
print(fruits)

dernier = fruits.pop()   # supprime le dernier
print(dernier)           # kiwi
# Out:
# ['pomme', 'cerise', 'kiwi']
# kiwi

# %% [markdown]
# ### ✏️ Modifier un élément

# %%
fruits[0] = "abricot"
print(fruits)          # ['abricot', 'cerise']
# Out:
# ['abricot', 'cerise']

# %% [markdown]
# ### 🔁 Parcourir une liste

# %%
for fruit in fruits:
    print(fruit.upper())
# Out:
# ABRICOT
# CERISE

# %% [markdown]
# ### 📏 Longueur

# %%
print(len(fruits))    # nombre d’éléments
# Out:
# 2

# %% [markdown]
# ### 🔍 Rechercher

# %%
print("kiwi" in fruits)     # False
# Out:
# False

# %% [markdown]
# ### 🧪 Exemple complet

# %%
notes = [14, 16.5, 12]
moyenne = sum(notes) / len(notes)
print(f"Notes : {notes}")
print(f"Moyenne : {moyenne:.1f}")
# Out:
# Notes : [14, 16.5, 12]
# Moyenne : 14.2

# %% [markdown]
# ### 🧠 Exercice
# ## ✏️ Énoncé :
#
# 1) Crée une liste appelée courses contenant 3 aliments.
#
# 2) Affiche la liste complète.
#
# 3) Ajoute un 4e élément via append().
#
# 4) Supprime le 2e élément (par index ou valeur).
#
# 5) Affiche un message pour chaque aliment restant :
#
# Tu dois acheter : pomme

# %%
# Ton code ici

# %% [markdown]
# # 🔒 Tuples en Python
# Un tuple est une collection ordonnée mais immuable.
# Une fois créé, on ne peut plus le modifier (contrairement aux listes).

# %% [markdown]
# ### 🔧 Création et lecture

# %%
coordonnees = (10, 20)
print(coordonnees)       # (10, 20)
print(coordonnees[0])    # 10
# Out:
# (10, 20)
# 10

# %% [markdown]
# ✅ Astuce : même avec un seul élément, il faut une virgule → (5,) sinon ce n’est pas un tuple.

# %% [markdown]
# ### 🛑 Tentative de modification → erreur

# %%
coordonnees[0] = 99
# TypeError: 'tuple' object does not support item assignment
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 coordonnees[0] = 99
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### 🔁 Parcours d’un tuple

# %%
dimensions = (1920, 1080)

for dim in dimensions:
    print(dim)
# Out:
# 1920
# 1080

# %% [markdown]
# ### 📏 Longueur

# %%
print(len(dimensions))   # 2
# Out:
# 2

# %% [markdown]
# ### 📦 Déballage (unpacking)

# %%
nom, age = ("Alice", 25)
print(nom)     # Alice
print(age)     # 25
# Out:
# Alice
# 25

# %% [markdown]
# ### ✅ Exemple combiné

# %%
film = ("Inception", 2010, "Christopher Nolan")
titre, annee, realisateur = film

print(f"{titre} est sorti en {annee}, réalisé par {realisateur}.")
# Out:
# Inception est sorti en 2010, réalisé par Christopher Nolan.

# %% [markdown]
# ### 🧠 Exercice
# ## ✏️ Énoncé :
#
# 1) Crée un tuple appelé voiture avec 3 infos : marque, modèle, année.
#
# 2) Décompose ce tuple en 3 variables.
#
# 3) Affiche un message comme :
#
# Tu conduis une Peugeot 208 de 2018.

# %%
#Ton code ici

# %% [markdown]
# # 📘 Dictionnaires en Python (dict)
# Un dictionnaire est une structure qui associe des clés à des valeurs, comme un mini-tableau avec des étiquettes.

# %% [markdown]
# ### 🔧 Création et lecture

# %%
eleve = {
    "nom": "Durand",
    "prenom": "Alice",
    "age": 17
}

print(eleve["nom"])       # Durand
print(eleve.get("prenom"))  # Alice
# Out:
# Durand
# Alice

# %% [markdown]
# ### ✍️ Ajout ou modification

# %%
eleve["classe"] = "Terminale"
eleve["age"] = 18

# %% [markdown]
# ### 🗑 Suppression

# %%
del eleve["age"]
# ou
eleve.pop("classe")
# Out:
# 'Terminale'

# %% [markdown]
# ### 🔁 Parcourir un dictionnaire

# %%
for cle, valeur in eleve.items():
    print(f"{cle} : {valeur}")
# Out:
# nom : Durand
# prenom : Alice

# %% [markdown]
# ### 🔍 Tester la présence d’une clé

# %%
if "age" in eleve:
    print("Âge connu :", eleve["age"])

# %% [markdown]
# ### 📏 Longueur

# %%
print(len(eleve))    # nombre de paires clé:valeur
# Out:
# 2

# %% [markdown]
# ### ✅ Exemple combiné

# %%
produit = {
    "nom": "Clavier",
    "prix": 29.99,
    "stock": 42
}

print(f"{produit['nom']} coûte {produit['prix']} € ({produit['stock']} en stock)")
# Out:
# Clavier coûte 29.99 € (42 en stock)

# %% [markdown]
# ### 🧠 Exercice
# ### ✏️ Énoncé :
# Crée un dictionnaire film avec 3 clés :
#
# "titre" (ex: "Interstellar")
#
# "année" (ex: 2014)
#
# "réalisateur" (ex: "Christopher Nolan")
#
# Affiche une phrase comme :
#
# Le film Interstellar (2014) a été réalisé par Christopher Nolan.
#
# Ajoute une clé "durée" puis affiche un message comme :
#
# Durée du film : 169 minutes

# %%
# Ton code ici

# %% [markdown]
# # 🧭 Contrôle de flux : if, elif, else

# %% [markdown]
# ### 🔧 Structure de base

# %%
age = 18

if age < 18:
    print("Mineur")
elif age == 18:
    print("Tout juste majeur")
else:
    print("Majeur confirmé")
# Out:
# Tout juste majeur

# %% [markdown]
# ✅ Indentation obligatoire : 4 espaces ou une tabulation

# %% [markdown]
# ### 🧠 Conditions possibles
#
# - == : égalité
#
# - != : différent
#
# - <, >, <=, >= : comparateurs
#
# - and, or, not : logique

# %%
note = 15

if note >= 10 and note < 16:
    print("Assez bien")
elif note >= 16:
    print("Très bien")
else:
    print("Échec")
# Out:
# Assez bien

# %% [markdown]
# ### 💡 Exemple avec booléens

# %%
connecte = True
admin = False

if connecte and admin:
    print("Bienvenue, administrateur.")
elif connecte:
    print("Bienvenue, utilisateur.")
else:
    print("Veuillez vous connecter.")
# Out:
# Bienvenue, utilisateur.

# %% [markdown]
# ### 🧠 Exercice
# ### ✏️ Énoncé :
#
# Écris un programme qui :
#
# 1) Demande à l’utilisateur son âge (int(input(...))).
#
# 2) Affiche un message selon l’âge :
#
# - Moins de 12 ans → Enfant
#
# - Entre 12 et 17 ans → Adolescent
#
# - Entre 18 et 64 ans → Adulte
#
# - 65 ans ou plus → Senior

# %%
# Ton code ici

# %% [markdown]
# ## 🛠 Gestion d’exception : try / except

# %% [markdown]
# ### 🔧 Structure de base

# %%
try:
    # Code qui pourrait planter
    x = int(input("Tape un nombre entier : "))
    print("Tu as saisi :", x)
except:
    print("Ce n'était pas un entier valide.")
# Out:
# Tape un nombre entier :  ff
# Ce n'était pas un entier valide.

# %% [markdown]
# 🧠 Python exécute le bloc try
# → s’il y a une erreur, il saute au except.

# %% [markdown]
# ### ✅ Version avec type d’erreur précisé

# %%
try:
    resultat = 10 / 0
except ZeroDivisionError:
    print("Erreur : division par zéro interdite.")
# Out:
# Erreur : division par zéro interdite.

# %% [markdown]
# ### ✨ Avec message d'erreur système

# %% [markdown]
# try:
#     num = int("abc")
# except ValueError as e:
#     print("Erreur :", e)

# %% [markdown]
# ### 🧹 Optionnel : finally (exécuté quoi qu’il arrive)

# %%
try:
    print("Traitement…")
except:
    print("Erreur")
finally:
    print("Nettoyage terminé.")
# Out:
# Traitement…
# Nettoyage terminé.

# %% [markdown]
# ### 🧠 Exercice
# ### ✏️ Énoncé :
#
# 1) Demande à l’utilisateur un nombre entier.
#
# 2) Affiche le carré du nombre.
#
# 3) Si l’utilisateur entre autre chose, affiche :
#
# "Entrée invalide. Veuillez entrer un entier."

# %%
# Ton code ici
